# %%
import sys
sys.executable
# Out:
# '/nix/store/nn1bb0x31hx8dws60qbjrzxdp6h6f62x-python3-3.9.6-env/bin/python3.9'

# %%
# !pip freeze
# Out:
# aiodns @ file:///build/source/dist/aiodns-3.0.0-py3-none-any.whl
# aiohttp @ file:///build/aiohttp-3.8.0/dist/aiohttp-3.8.0-cp39-cp39-linux_x86_64.whl
# aiosignal @ file:///build/source/dist/aiosignal-1.2.0-py3-none-any.whl
# argon2-cffi @ file:///build/argon2-cffi-21.1.0/dist/argon2_cffi-21.1.0-cp39-abi3-linux_x86_64.whl
# artiq @ file:///build/source/dist/artiq-7.7999.71e8b49.beta-py3-none-any.whl
# artiq-comtools @ file:///build/source/dist/artiq_comtools-1.0-py3-none-any.whl
# async-generator @ file:///build/async_generator-1.10/dist/async_generator-1.10-py3-none-any.whl
# async-timeout @ file:///build/async-timeout-4.0.1/dist/async_timeout-4.0.1-py3-none-any.whl
# attrs @ file:///build/attrs-21.2.0/dist/attrs-21.2.0-py2.py3-none-any.whl
# Babel @ file:///build/Babel-2.9.1/dist/Babel-2.9.1-py2.py3-none-any.whl
# backcall @ file:///build/backcall-0.2.0/dist/backcall-0.2.0-py3-none-any.whl
# bleach @ file:///build/bleach-4.1.0/dist/bleach-4.1.0-py2.py3-none-any.whl
# ...

# %%
import artiq
artiq.__version__
# Out:
# '7.7999.71e8b49.beta'
